# %%
import pandas as pd
import numpy as np

# to bypass warnings
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "/home/dcti-02-11/projects/data/NYC_Taxi_Trips/data/2020_taxi_trips.csv"

trips_2020 = pd.read_csv(file_path)

# %%
trips_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1205954 entries, 0 to 1730575
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1205954 non-null  float64
#  1   lpep_pickup_datetime   1205954 non-null  object
#  2   lpep_dropoff_datetime  1205954 non-null  object
#  3   store_and_fwd_flag     1205954 non-null  bool
#  4   RatecodeID             1205954 non-null  float64
#  5   PULocationID           1205954 non-null  int64
#  6   DOLocationID           1205954 non-null  int64
#  7   passenger_count        1205954 non-null  float64
#  8   trip_distance          1205954 non-null  float64
#  9   fare_amount            1205954 non-null  float64
#  10  extra                  1205954 non-null  float64
#  11  mta_tax                1205954 non-null  float64
#  12  tip_amount             1205954 non-null  float64
#  13  tolls_amount           1205954 non-null  float64
#  14  improvement_surcharge  1205954 non-null  float64
#  15  total_amount           1205954 non-null  float64
#  16  payment_type           1205954 non-null  float64
#  17  trip_type              1205954 non-null  float64
#  18  congestion_surcharge   1205954 non-null  float64
# dtypes: bool(1), float64(14), int64(2), object(2)
# memory usage: 176.0+ MB

# %%
trips_2020 = trips_2020.dropna()

# %%
trips_2020.head()
# Out:
#   VendorID lpep_pickup_datetime lpep_dropoff_datetime  store_and_fwd_flag  \
# 0      2.0  2020-01-01 06:47:28   2020-01-01 06:52:54               False
# 1      2.0  2020-01-01 13:25:34   2020-01-01 13:30:43               False
# 2      2.0  2020-01-01 14:20:35   2020-01-01 14:26:25               False
# 3      2.0  2020-01-02 06:56:47   2020-01-02 07:03:03               False
# 4      2.0  2020-01-02 09:34:46   2020-01-02 09:41:02               False
#
#   RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0        1.0            74            75                1           1.47
# 1        1.0            74            75                1           1.49
# 2        1.0            74            75                1           1.31
# 3        1.0            74            75                1           1.43
# 4        1.0            74            75                1           1.10
#
#    fare_amount  ...  trip_type  congestion_surcharge  trip_distance_km  \
# 0          6.5  ...        1.0                   0.0          2.365736
# 1          6.5  ...        1.0                   0.0          2.397923
# 2          6.5  ...        1.0                   0.0          2.108241
# 3          6.5  ...        1.0                   0.0          2.301362
# 4          6.5  ...        1.0                   0.0          1.770278
#
#         time_diff  pickup_date  dropoff_date pickup_month dropoff_month  \
# 0 0 days 00:05:26   2020-01-01    2020-01-01            1             1
# 1 0 days 00:05:09   2020-01-01    2020-01-01            1             1
# 2 0 days 00:05:50   2020-01-01    2020-01-01            1             1
# 3 0 days 00:06:16   2020-01-02    2020-01-02            1             1
# 4 0 days 00:06:16   2020-01-02    2020-01-02            1             1
#
#    pickup_day  dropoff_day
# 0   Wednesday    Wednesday
# 1   Wednesday    Wednesday
# 2   Wednesday    Wednesday
# 3    Thursday     Thursday
# 4    Thursday     Thursday
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Replace and convert columns to the appropriate data types

# %%
# Replace Y and N with True and False respectively
trips_2020['store_and_fwd_flag'] = trips_2020['store_and_fwd_flag'].replace({'N':False, 'Y':True})

# %%
# convert the following columns to category
list_convert = ['VendorID','RatecodeID','payment_type','trip_type']
trips_2020[list_convert] = trips_2020[list_convert].astype('category')

# %%
# convert passenger count from float to int
trips_2020['passenger_count'] = trips_2020['passenger_count'].astype(int)

# %%
# convert pickup and dropoff to datetime
trips_2020['lpep_pickup_datetime'] = pd.to_datetime(trips_2020['lpep_pickup_datetime'])
trips_2020['lpep_dropoff_datetime'] = pd.to_datetime(trips_2020['lpep_dropoff_datetime'])

# %% [markdown]
# ## Adding new Columns

# %%
# convert distance from miles to km
trips_2020['trip_distance_km'] = trips_2020['trip_distance'] * 1.609344

# %%
# get time difference from dropoff and pickup
trips_2020['time_diff'] = trips_2020['lpep_dropoff_datetime'] - trips_2020['lpep_pickup_datetime']

# %%
# get the pickup and dropoffs dates only
trips_2020['pickup_date'] = pd.to_datetime(trips_2020['lpep_pickup_datetime'].dt.date)
trips_2020['dropoff_date'] = pd.to_datetime(trips_2020['lpep_dropoff_datetime'].dt.date)

# %%
# add columns for month of the year
trips_2020['pickup_month'] = trips_2020['pickup_date'].dt.month
trips_2020['dropoff_month'] = trips_2020['dropoff_date'].dt.month

# %%
# add columns for day of the week
trips_2020['pickup_day'] = trips_2020['pickup_date'].dt.day_name()
trips_2020['dropoff_day'] = trips_2020['dropoff_date'].dt.day_name()

# %% [markdown]
# ## Remove negative distances and negative days

# %%
# remove rows with trip distance less that 0
trips_2020 = trips_2020[trips_2020['trip_distance_km'] > 0]

# %%
# remove negative time difference
trips_2020 = trips_2020[trips_2020['time_diff'] > pd.Timedelta(0)]

# %%
trips_2020['fare_amount'].value_counts()

# %%
trips_2020.trip_distance_km.value_counts()

# %%
trips_2020['time_diff'].max()
# Out:
# Timedelta('0 days 23:59:58')

# %%
trips_2020.tail()
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 1730033      2.0  2020-12-09 15:22:43   2020-12-09 15:31:23
# 1730034      2.0  2020-12-11 10:55:38   2020-12-11 11:05:31
# 1730035      2.0  2020-12-16 14:35:14   2020-12-16 14:48:01
# 1730036      2.0  2020-12-16 14:03:48   2020-12-16 14:13:28
# 1730037      2.0  2020-12-22 15:51:20   2020-12-22 16:00:48
#
#          store_and_fwd_flag RatecodeID  PULocationID  DOLocationID  \
# 1730033               False        1.0           244           220
# 1730034               False        1.0           244           220
# 1730035               False        1.0           244           220
# 1730036               False        1.0           244           220
# 1730037               False        1.0           244           220
#
#          passenger_count  trip_distance  fare_amount  ...  trip_type  \
# 1730033                1           3.65         12.0  ...        1.0
# 1730034                1           4.06         13.5  ...        1.0
# 1730035                1           3.27         13.0  ...        1.0
# 1730036                1           3.87         13.0  ...        1.0
# 1730037                1           3.50         13.0  ...        1.0
#
#          congestion_surcharge  trip_distance_km       time_diff  pickup_date  \
# 1730033                   0.0          5.874106 0 days 00:08:40   2020-12-09
# 1730034                   0.0          6.533937 0 days 00:09:53   2020-12-11
# 1730035                   0.0          5.262555 0 days 00:12:47   2020-12-16
# 1730036                   0.0          6.228161 0 days 00:09:40   2020-12-16
# 1730037                   0.0          5.632704 0 days 00:09:28   2020-12-22
#
#          dropoff_date pickup_month dropoff_month  pickup_day  dropoff_day
# 1730033    2020-12-09           12            12   Wednesday    Wednesday
# 1730034    2020-12-11           12            12      Friday       Friday
# 1730035    2020-12-16           12            12   Wednesday    Wednesday
# 1730036    2020-12-16           12            12   Wednesday    Wednesday
# 1730037    2020-12-22           12            12     Tuesday      Tuesday
#
# [5 rows x 27 columns]

# %%
trips_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1146566 entries, 0 to 1730037
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1146566 non-null  category
#  1   lpep_pickup_datetime   1146566 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  1146566 non-null  datetime64[ns]
#  3   store_and_fwd_flag     1146566 non-null  bool
#  4   RatecodeID             1146566 non-null  category
#  5   PULocationID           1146566 non-null  int64
#  6   DOLocationID           1146566 non-null  int64
#  7   passenger_count        1146566 non-null  int64
#  8   trip_distance          1146566 non-null  float64
#  9   fare_amount            1146566 non-null  float64
#  10  extra                  1146566 non-null  float64
#  11  mta_tax                1146566 non-null  float64
#  12  tip_amount             1146566 non-null  float64
#  13  tolls_amount           1146566 non-null  float64
#  14  improvement_surcharge  1146566 non-null  float64
#  15  total_amount           1146566 non-null  float64
#  16  payment_type           1146566 non-null  category
#  17  trip_type              1146566 non-null  category
#  18  congestion_surcharge   1146566 non-null  float64
#  19  trip_distance_km       1146566 non-null  float64
#  20  time_diff              1146566 non-null  timedelta64[ns]
#  21  pickup_date            1146566 non-null  datetime64[ns]
#  22  dropoff_date           1146566 non-null  datetime64[ns]
#  23  pickup_month           1146566 non-null  int64
#  24  dropoff_month          1146566 non-null  int64
#  25  pickup_day             1146566 non-null  object
#  26  dropoff_day            1146566 non-null  object
# dtypes: bool(1), category(4), datetime64[ns](4), float64(10), int64(5), object(2), timedelta64[ns](1)
# memory usage: 206.7+ MB

# %%
trips_2020.isna().mean() * 100

# %%
trips_2020.groupby(['pickup_day']).count()
# Out:
#             VendorID  lpep_pickup_datetime  lpep_dropoff_datetime  \
# pickup_day
# Friday        188044                188044                 188044
# Monday        152201                152201                 152201
# Saturday      167063                167063                 167063
# Sunday        129712                129712                 129712
# Thursday      179228                179228                 179228
# Tuesday       158021                158021                 158021
# Wednesday     172297                172297                 172297
#
#             store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# pickup_day
# Friday                  188044      188044        188044        188044
# Monday                  152201      152201        152201        152201
# Saturday                167063      167063        167063        167063
# Sunday                  129712      129712        129712        129712
# Thursday                179228      179228        179228        179228
# Tuesday                 158021      158021        158021        158021
# Wednesday               172297      172297        172297        172297
#
#             passenger_count  trip_distance  fare_amount  ...  payment_type  \
# pickup_day                                               ...
# Friday               188044         188044       188044  ...        188044
# Monday               152201         152201       152201  ...        152201
# Saturday             167063         167063       167063  ...        167063
# Sunday               129712         129712       129712  ...        129712
# Thursday             179228         179228       179228  ...        179228
# Tuesday              158021         158021       158021  ...        158021
# Wednesday            172297         172297       172297  ...        172297
#
#             trip_type  congestion_surcharge  trip_distance_km  time_diff  \
# pickup_day
# Friday         188044                188044            188044     188044
# Monday         152201                152201            152201     152201
# Saturday       167063                167063            167063     167063
# Sunday         129712                129712            129712     129712
# Thursday       179228                179228            179228     179228
# Tuesday        158021                158021            158021     158021
# Wednesday      172297                172297            172297     172297
#
#             pickup_date  dropoff_date  pickup_month  dropoff_month  \
# pickup_day
# Friday           188044        188044        188044         188044
# Monday           152201        152201        152201         152201
# Saturday         167063        167063        167063         167063
# Sunday           129712        129712        129712         129712
# Thursday         179228        179228        179228         179228
# Tuesday          158021        158021        158021         158021
# Wednesday        172297        172297        172297         172297
#
#             dropoff_day
# pickup_day
# Friday           188044
# Monday           152201
# Saturday         167063
# Sunday           129712
# Thursday         179228
# Tuesday          158021
# Wednesday        172297
#
# [7 rows x 26 columns]

# %%
trips_2020.groupby(['pickup_day']).sum()
# Out:
#             store_and_fwd_flag  PULocationID  DOLocationID  passenger_count  \
# pickup_day
# Friday                     629      18820034      24013929           243523
# Monday                     489      15378125      19881830           196703
# Saturday                   508      16814222      21333662           217613
# Sunday                     386      13143679      16755656           170797
# Thursday                   577      18065228      23176846           233665
# Tuesday                    486      15867832      20582638           205137
# Wednesday                  551      17263655      22357098           224268
#
#             trip_distance  fare_amount     extra   mta_tax  tip_amount  \
# pickup_day
# Friday          558818.76   2326032.50  90057.50  91546.00   234250.18
# Monday          517113.43   1903194.57  66537.75  74095.50   190920.65
# Saturday        530732.38   2074780.18  38125.00  81021.60   203444.49
# Sunday          400339.52   1606442.89  30563.26  62876.05   164318.10
# Thursday        520409.85   2218944.33  84622.00  87262.00   230534.81
# Tuesday         468059.86   1976475.32  72546.25  77073.65   201934.87
# Wednesday       755252.70   2164403.90  79347.00  83839.50   223383.06
#
#             tolls_amount  improvement_surcharge  total_amount  \
# pickup_day
# Friday          33718.63                55788.3    2909285.51
# Monday          29724.05                45138.6    2381657.92
# Saturday        27587.40                49494.9    2545071.92
# Sunday          22611.45                38455.5    1983173.80
# Thursday        32772.43                53173.8    2789931.22
# Tuesday         30383.95                46892.4    2481107.84
# Wednesday       33575.22                51110.1    2717573.73
#
#             congestion_surcharge  trip_distance_km  pickup_month  \
# pickup_day
# Friday                  87510.75      8.993316e+05        701932
# Monday                  81443.75      8.322134e+05        624647
# Saturday                78390.75      8.541310e+05        632670
# Sunday                  64805.50      6.442840e+05        481420
# Thursday                92823.25      8.375185e+05        684092
# Tuesday                 85612.00      7.532693e+05        648246
# Wednesday               91526.50      1.215461e+06        678787
#
#             dropoff_month
# pickup_day
# Friday             702100
# Monday             624669
# Saturday           632865
# Sunday             481429
# Thursday           683988
# Tuesday            648158
# Wednesday          678804

# %%
trips_2020.groupby(['pickup_month'])['total_amount', 'tip_amount','congestion_surcharge'].max()
# Out:
#               total_amount  tip_amount  congestion_surcharge
# pickup_month
# 1                   753.80      450.00                  2.75
# 2                   651.50      641.20                  2.75
# 3                   462.27      449.97                  2.75
# 4                   398.76      100.00                  2.75
# 5                   655.30      160.00                  2.75
# 6                   498.80      480.00                  2.75
# 7                   803.80       88.00                  2.75
# 8                   550.80      200.00                  2.75
# 9                   537.85       89.06                  2.75
# 10                  257.92      111.60                  2.75
# 11                  325.30      101.00                  2.75
# 12                  393.64       90.84                  2.75
